# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
data=pd.read_csv(r"C:\Users\adity\Documents\6 sem tiet\ML\sonar.csv")
data=np.array(data)
data_samples=data[:,:-1]
data_target=data[:,-1]
rocks=np.zeros(96)
mines=np.ones(111)
target=np.concatenate((rocks,mines),axis=0)
df=pd.DataFrame(data_samples)
df['target']=target

from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.iloc[:,:-1],df['target'],test_size=0.2,random_state=0)
# accu=[]
# for n in range(1,11):
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train,y_train)
pred=knn.predict(X_test)
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, pred)
#     accuracy=accuracy_score(y_test,pred)
#     accu.append(accuracy)
# plt.plot(range(1,11),accu)
# Out:
# 0.14285714285714285

# %%
#Reading sonar data file into the environment
import numpy as np
import pandas as pd
data = pd.read_csv(r"C:\Users\adity\Downloads\sonar.all-data") 
sonar_data=np.array(data)
samples=sonar_data[:,:-1]
print(samples.shape)
rocks_labels=np.zeros(96)
mines_labels=np.ones(111)
target=np.concatenate((rocks_labels,mines_labels),axis=0)
df=pd.DataFrame(samples)
df['target']=target
print(df.head())



from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df,df['target'],test_size=0.6,random_state=0)
# print(y_test)
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
tree=DecisionTreeClassifier(max_depth=3,random_state=0)
tree.fit(X_train,y_train)
pred=tree.predict(X_test)
accu=np.array([accuracy_score(pred,y_test)])
print(accu)
# # Knn
# from sklearn.neighbors import KNeighborsClassifier
# knn=KNeighborsClassifier(n_neighbors=3,random_state=0)
# np.append Hint 
# On x-axis= max_depth  = 2 to 10
# On x-axis = n_neighbors 1 to 10
# On y-axis Accuracy 
# On x-axis test_size 0.1-0.8
# On y-axis accuracy

# Randomly Choose
# sonar_data1=np.concatenate((samples,np.transpose(target)),axis=1)
# print(sonar_data1)
# Out:
# (207, 60)
#         0       1       2       3       4       5       6       7       8  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974   0.228  0.2431  0.3771  0.5598
# 2    0.01  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394   0.059  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384   0.099  0.1201  0.1833  0.2105
#
#         9  ...      51      52      53      54      55      56      57  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191   0.014  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095   0.018  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036   0.015  0.0085  0.0073   0.005  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105   0.011  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#        58      59 target
# 0  0.0052  0.0044    0.0
# 1  0.0095  0.0078    0.0
# ...

# %%
# Plotting multiple 3D scatter plots of the dataset
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
plt.figure(figsize=(14,16))
axes = plt.subplot(3,2,1, projection ='3d')
axes.plot(samples[0:95,0],samples[0:95,1],samples[0:95,2],"x",label="Rocks")
axes.plot(samples[96:206,0],samples[96:206,1],samples[96:206,2],"o",label="Mines")
axes.set_xlabel('Attribute 1')
axes.set_ylabel('Attribute 2')
axes.set_zlabel('Arrtibute 3')
plt.legend(loc="upper left")
#Second Plot
axes = plt.subplot(322, projection='3d')
axes.plot(samples[0:95,5],samples[0:95,6],samples[0:95,7],"x",label="Rocks")
axes.plot(samples[96:206,5],samples[96:206,6],samples[96:206,7],"o",label="Mines")
axes.set_xlabel('Attribute 6')
axes.set_ylabel('Attribute 7')
axes.set_zlabel('Arrtibute 8')
plt.legend(loc="upper left")
# Third Plot (First in row 2)
axes = plt.subplot(323, projection='3d')
axes.plot(samples[0:95,12],samples[0:95,13],samples[0:95,14],"x",label="Rocks")
axes.plot(samples[96:206,12],samples[96:206,13],samples[96:206,14],"o",label="Mines")
axes.set_xlabel('Attribute 13')
axes.set_ylabel('Attribute 14')
axes.set_zlabel('Arrtibute 15')
plt.legend(loc="upper left")
# Fourth Plot (Second in row 2)
axes = plt.subplot(324, projection='3d')
axes.plot(samples[0:95,30],samples[0:95,31],samples[0:95,32],"x",label="Rocks")
axes.plot(samples[96:206,30],samples[96:206,31],samples[96:206,32],"o",label="Mines")
axes.set_xlabel('Attribute 31')
axes.set_ylabel('Attribute 32')
axes.set_zlabel('Arrtibute 33')
plt.legend(loc="upper left")
# # # Fifth Plot (First in row 3)
# axes = plt.subplot(325, projection='3d')
# axes.plot(samples[0:95,40],samples[0:95,41],samples[0:95,42],"x",label="Rocks")
# axes.plot(samples[96:206,40],samples[96:206,41],samples[96:206,42],"o",label="Mines")
# plt.legend(loc="upper left")
# # Sixth Plot (Second in row 3)
# axes = plt.subplot(326, projection='3d')
# axes.plot(samples[0:95,51],samples[0:95,52],samples[0:95,53],"x",label="Rocks")
# axes.plot(samples[96:206,51],samples[96:206,52],samples[96:206,53],"o",label="Mines")
# plt.legend(loc="upper left")
plt.show()

# %%
data.iloc[:,-1],_=pd.factorize(data.iloc[:,-1])
data
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
data_train,data_test=train_test_split(data, test_size=0.2,random_state=0)
data_train=data_train.values
data_test=data_test.values

# %%
class_data_0=data_train[data_train[:, -1]==0, :]
class_data_1=data_train[data_train[:,-1]==1, :]

# %%
def transformed_cluster_analysis(class_data):
    variance=np.var(class_data[:,:-1],axis=0)
    var_gt_1=variance>=1
    class_data_var_gt_1=class_data[:,list(var_gt_1)+[True]]
    means_gt_1=np.means(class_data_var_gt_1, axis=0)
    #(((class_data_var_gt_1-mean_gt_1)**2)/np.var(class_data_var_gt_1, axis=0))+

# %% [markdown]
# # Python script to implement Principal Component Ananlysis (PCA).
